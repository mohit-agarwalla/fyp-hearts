# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
import os 

os.chdir('../..')

# %%
modelnames = ['AttNet+Baseline+lead1', 'ResNet+Baseline+lead1', 
          'VGGNet+lead1', 'AlexNet+lead1', 'LeNet+lead1', 
          'NewWavelet+NN+lead1', 'Wavelet+NN+lead1']

# %%
from tensorflow.keras.models import load_model

# %%
for name in modelnames:
    print(name)
    try:
        model = load_model(f"C://Mohit/Imperial/fyp-hearts/output/exp4/models/{name}/last_model.h5")
        model.summary()
    except:
        pass
# Out:
# AttNet+Baseline+lead1
# ResNet+Baseline+lead1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 1000, 1)]    0           []
#
#  conv1d (Conv1D)                (None, 500, 64)      512         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 500, 64)     256         ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 500, 64)      0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 500, 64)      12352       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 500, 64)     256         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 500, 64)      0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 500, 64)      12352       ['activation_1[0][0]']
#
# ...

# %%
from models.attnet_demo import AttentionWithContext
from utils import CustomMetric

# %%
model = load_model(f"C://Mohit/Imperial/fyp-hearts/output/exp4/models/AttNet+Baseline+lead1/last_model.h5", custom_objects={'AttentionWithContext': AttentionWithContext})
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 1000, 1)]         0
#
#  conv1d (Conv1D)             (None, 1000, 12)          48
#
#  leaky_re_lu (LeakyReLU)     (None, 1000, 12)          0
#
#  conv1d_1 (Conv1D)           (None, 1000, 12)          444
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 1000, 12)          0
#
#  conv1d_2 (Conv1D)           (None, 500, 12)           444
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 500, 12)           0
#
#  dropout (Dropout)           (None, 500, 12)           0
#
#  conv1d_3 (Conv1D)           (None, 500, 12)           444
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 500, 12)           0
#
#  conv1d_4 (Conv1D)           (None, 500, 12)           444
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 500, 12)           0
#
#  conv1d_5 (Conv1D)           (None, 250, 12)           3468
#
# ...

# %%
model = load_model(f"C://Mohit/Imperial/fyp-hearts/output/exp4/models/LeNet+lead1/last_model.h5", custom_objects={'CustomMetric': CustomMetric})
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 1000, 6)           24
#
#  batch_normalization (BatchN  (None, 1000, 6)          24
#  ormalization)
#
#  activation (Activation)     (None, 1000, 6)           0
#
#  max_pooling1d (MaxPooling1D  (None, 500, 6)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 496, 16)           496
#
#  batch_normalization_1 (Batc  (None, 496, 16)          64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 496, 16)           0
#
#  max_pooling1d_1 (MaxPooling  (None, 248, 16)          0
#  1D)
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                1088
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 43)                1419
#
# ...
# Total params: 5,195
# ...
